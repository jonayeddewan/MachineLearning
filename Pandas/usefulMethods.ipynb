# %%
import numpy as np 
import pandas as pd

# %%
def last_four(num):
    return str(num)[-4:]

# %%
df = pd.read_csv('tips.csv')

# %%
last_four(123456789)
# Out:
# '6789'

# %%
df['last_four'] = df['RollId'].apply(last_four)

# %%
df
# Out:
#              StudentName   RollId  RegistrationId                StudentEmail  \
# 0          Rahul Debnath  2010001            1055  2010001@student.ruet.ac.bd
# 1   Humayra Tasnim Adiba  2010002            1056  2010002@student.ruet.ac.bd
# 2            Mahin Ahsan  2010003            1057  2010003@student.ruet.ac.bd
# 3           Kamrul Islam  2010004            1058  2010004@student.ruet.ac.bd
# 4         Maysha Iyasmin  2010005            1059  2010005@student.ruet.ac.bd
# ..                   ...      ...             ...                         ...
# 56        Brayden Wright  2010057            1111  2010057@student.ruet.ac.bd
# 57           Sofia Lopez  2010058            1112  2010058@student.ruet.ac.bd
# 58        Zachary Harris  2010059            1113  2010059@student.ruet.ac.bd
# 59         AveryMartinez  2010060            1114  2010060@student.ruet.ac.bd
# 60        Isaac Thompson  2010061            1115  2010061@student.ruet.ac.bd
#
# ...

# %%
lambda num: num*2
# Out:
# <function __main__.<lambda>(num)>

# %%
df['RollId'].apply(lambda num : num*2)
# Out:
# 0     4020002
# 1     4020004
# 2     4020006
# 3     4020008
# 4     4020010
#        ...
# 56    4020114
# 57    4020116
# 58    4020118
# 59    4020120
# 60    4020122
# Name: RollId, Length: 61, dtype: int64

# %%
def quality(total_bill,tip):
    if tip/total_bill > 0.25:
        return "Generous"
    else:
        return "Other"

# %%
quality(16.99,1.01)
# Out:
# 'Other'

# %%
df['Quality'] = df[['total_bill','tip']].apply(lambda df: quality(df['total_bill'],df['tip']),axis=1)

# %%
df['Quality'] = np.vectorize(quality)(df['total_bill'],df['tip'])

# %%
import timeit

# %%
df = pd.read_csv('tips.csv')

# %%
df.describe()
# Out:
#              RollId  RegistrationId  Series       Contact  Status
# count  6.100000e+01       61.000000    61.0  6.100000e+01    61.0
# mean   2.010031e+06     1085.000000  2020.0  1.912153e+09     1.0
# std    1.775293e+01       17.752934     0.0  0.000000e+00     0.0
# min    2.010001e+06     1055.000000  2020.0  1.912153e+09     1.0
# 25%    2.010016e+06     1070.000000  2020.0  1.912153e+09     1.0
# 50%    2.010031e+06     1085.000000  2020.0  1.912153e+09     1.0
# 75%    2.010046e+06     1100.000000  2020.0  1.912153e+09     1.0
# max    2.010061e+06     1115.000000  2020.0  1.912153e+09     1.0

# %%
df.describe().transpose()
# Out:
#                 count          mean        std           min           25%  \
# RollId           61.0  2.010031e+06  17.752934  2.010001e+06  2.010016e+06
# RegistrationId   61.0  1.085000e+03  17.752934  1.055000e+03  1.070000e+03
# Series           61.0  2.020000e+03   0.000000  2.020000e+03  2.020000e+03
# Contact          61.0  1.912153e+09   0.000000  1.912153e+09  1.912153e+09
# Status           61.0  1.000000e+00   0.000000  1.000000e+00  1.000000e+00
#
#                          50%           75%           max
# RollId          2.010031e+06  2.010046e+06  2.010061e+06
# RegistrationId  1.085000e+03  1.100000e+03  1.115000e+03
# Series          2.020000e+03  2.020000e+03  2.020000e+03
# Contact         1.912153e+09  1.912153e+09  1.912153e+09
# Status          1.000000e+00  1.000000e+00  1.000000e+00

# %%
df.sort_values('RollId', ascending=False)
# Out:
#              StudentName   RollId  RegistrationId                StudentEmail  \
# 60        Isaac Thompson  2010061            1115  2010061@student.ruet.ac.bd
# 59         AveryMartinez  2010060            1114  2010060@student.ruet.ac.bd
# 58        Zachary Harris  2010059            1113  2010059@student.ruet.ac.bd
# 57           Sofia Lopez  2010058            1112  2010058@student.ruet.ac.bd
# 56        Brayden Wright  2010057            1111  2010057@student.ruet.ac.bd
# ..                   ...      ...             ...                         ...
# 4         Maysha Iyasmin  2010005            1059  2010005@student.ruet.ac.bd
# 3           Kamrul Islam  2010004            1058  2010004@student.ruet.ac.bd
# 2            Mahin Ahsan  2010003            1057  2010003@student.ruet.ac.bd
# 1   Humayra Tasnim Adiba  2010002            1056  2010002@student.ruet.ac.bd
# 0          Rahul Debnath  2010001            1055  2010001@student.ruet.ac.bd
#
# ...

# %%
df.sort_values(['RollId', 'StudentName'])
# Out:
#              StudentName   RollId  RegistrationId                StudentEmail  \
# 0          Rahul Debnath  2010001            1055  2010001@student.ruet.ac.bd
# 1   Humayra Tasnim Adiba  2010002            1056  2010002@student.ruet.ac.bd
# 2            Mahin Ahsan  2010003            1057  2010003@student.ruet.ac.bd
# 3           Kamrul Islam  2010004            1058  2010004@student.ruet.ac.bd
# 4         Maysha Iyasmin  2010005            1059  2010005@student.ruet.ac.bd
# ..                   ...      ...             ...                         ...
# 56        Brayden Wright  2010057            1111  2010057@student.ruet.ac.bd
# 57           Sofia Lopez  2010058            1112  2010058@student.ruet.ac.bd
# 58        Zachary Harris  2010059            1113  2010059@student.ruet.ac.bd
# 59         AveryMartinez  2010060            1114  2010060@student.ruet.ac.bd
# 60        Isaac Thompson  2010061            1115  2010061@student.ruet.ac.bd
#
# ...

# %%
df['RollId'].max()
# Out:
# np.int64(2010061)

# %%
df['RollId'].idxmax()
# Out:
# 60

# %%
df.iloc[60]
# Out:
# StudentName                   Isaac Thompson
# RollId                               2010061
# RegistrationId                          1115
# StudentEmail      2010061@student.ruet.ac.bd
# Gender                                  Male
# Department                               ECE
# Section                                    A
# Series                                  2020
# DOB                               1995-12-15
# FatherName                              Test
# MotherName                              Test
# Contact                           1912153465
# Status                                     1
# Name: 60, dtype: object

# %%
df.corr()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 df.corr()
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:11049, in DataFrame.corr(self, method, min_periods, numeric_only)
#   11047 cols = data.columns
#   11048 idx = cols.copy()
# > 11049 mat = data.to_numpy(dtype=float, na_value=np.nan, copy=False)
#   11051 if method == "pearson":
#   11052     correl = libalgos.nancorr(mat, minp=min_periods)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:1993, in DataFrame.to_numpy(self, dtype, copy, na_value)
#    1991 if dtype is not None:
#    1992     dtype = np.dtype(dtype)
# -> 1993 result = self._mgr.as_array(dtype=dtype, copy=copy, na_value=na_value)
#    1994 if result.dtype is not dtype:
# ...

# %%
df.head()
# Out:
#             StudentName   RollId  RegistrationId                StudentEmail  \
# 0         Rahul Debnath  2010001            1055  2010001@student.ruet.ac.bd
# 1  Humayra Tasnim Adiba  2010002            1056  2010002@student.ruet.ac.bd
# 2           Mahin Ahsan  2010003            1057  2010003@student.ruet.ac.bd
# 3          Kamrul Islam  2010004            1058  2010004@student.ruet.ac.bd
# 4        Maysha Iyasmin  2010005            1059  2010005@student.ruet.ac.bd
#
#    Gender Department Section  Series         DOB FatherName MotherName  \
# 0    Male        ECE       A    2020  1995-03-03       Test       Test
# 1  Female        ECE       A    2020  1994-02-02       Test       Test
# 2    Male        ECE       A    2020  1993-08-06       Test       Test
# 3    Male        ECE       A    2020  1992-02-03       Test       Test
# 4  Female        ECE       A    2020  1991-02-03       Test       Test
#
#       Contact  Status
# 0  1912153465       1
# 1  1912153465       1
# ...

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Male      34
# Female    27
# Name: count, dtype: int64

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
#       ...
# 56    False
# 57    False
# 58    False
# 59    False
# 60    False
# Length: 61, dtype: bool

# %%
sample_df = pd.DataFrame([1,2,2,2],['a','b','c','d'])

# %%
sample_df
# Out:
#    0
# a  1
# b  2
# c  2
# d  2

# %%
sample_df.duplicated()
# Out:
# a    False
# b    False
# c     True
# d     True
# dtype: bool

# %%
sample_df.drop_duplicates()
# Out:
#    0
# a  1
# b  2

# %%
df.nlargest(2,'tip')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tip'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[80], line 1
# ----> 1 df.nlargest(2,'tip')
#
# ...

# %%
df.sort_values('tip', ascending=False).iloc[0:2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_18604\312726665.py in ?()
# ----> 1 df.sort_values('tip', ascending=False).iloc[0:2]
#
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py in ?(self, by, axis, ascending, inplace, kind, na_position, ignore_index, key)
#    7185             )
#    7186         elif len(by):
#    7187             # len(by) == 1
#    7188
# -> 7189             k = self._get_label_or_level_values(by[0], axis=axis)
#    7190
#    7191             # need to rewrap column in Series to apply key function
#    7192             if key is not None:
#
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
# ...

# %%
df.nsmallest(2,'tip')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'tip'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[84], line 1
# ----> 1 df.nsmallest(2,'tip')
#
# ...

# %%
df.sample(5)
# Out:
#        StudentName   RollId  RegistrationId                StudentEmail  \
# 58  Zachary Harris  2010059            1113  2010059@student.ruet.ac.bd
# 14   Iyasin Arafat  2010015            1069  2010015@student.ruet.ac.bd
# 9      Samira Khan  2010010            1064  2010010@student.ruet.ac.bd
# 25     Ashley Hill  2010026            1080  2010026@student.ruet.ac.bd
# 11    Sajid Rahman  2010012            1066  2010012@student.ruet.ac.bd
#
#     Gender Department Section  Series         DOB FatherName MotherName  \
# 58    Male        ECE       A    2020  1991-06-29       Test       Test
# 14    Male        ECE       A    2020  1993-02-14       Test       Test
# 9   Female        ECE       A    2020  1992-01-22       Test       Test
# 25  Female        ECE       A    2020  1994-12-15       Test       Test
# 11    Male        ECE       A    2020  1990-05-27       Test       Test
#
#        Contact  Status
# 58  1912153465       1
# 14  1912153465       1
# 9   1912153465       1
# ...
