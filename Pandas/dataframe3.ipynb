# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('tips.csv')

# %%
df
# Out:
#              StudentName   RollId  RegistrationId  \
# 0          Rahul Debnath  2010001            1055
# 1   Humayra Tasnim Adiba  2010002            1056
# 2            Mahin Ahsan  2010003            1057
# 3           Kamrul Islam  2010004            1058
# 4         Maysha Iyasmin  2010005            1059
# ..                   ...      ...             ...
# 56        Brayden Wright  2010057          '1111'
# 57           Sofia Lopez  2010058          '1112'
# 58        Zachary Harris  2010059          '1113'
# 59        Avery Martinez  2010060          '1114'
# 60        Isaac Thompson  2010061          '1115'
#
#                      StudentEmail     Gender  Department  Section   Series  \
# 0      2010001@student.ruet.ac.bd       Male         ECE        A     2020
# 1      2010002@student.ruet.ac.bd     Female         ECE        A     2020
# 2      2010003@student.ruet.ac.bd       Male         ECE        A     2020
# ...

# %%
df.head()
# Out:
#             StudentName   RollId  RegistrationId                 StudentEmail  \
# 0         Rahul Debnath  2010001            1055   2010001@student.ruet.ac.bd
# 1  Humayra Tasnim Adiba  2010002            1056   2010002@student.ruet.ac.bd
# 2           Mahin Ahsan  2010003            1057   2010003@student.ruet.ac.bd
# 3          Kamrul Islam  2010004            1058   2010004@student.ruet.ac.bd
# 4        Maysha Iyasmin  2010005            1059   2010005@student.ruet.ac.bd
#
#     Gender  Department  Section   Series          DOB  FatherName  MotherName  \
# 0     Male         ECE        A     2020   1995-03-03        Test        Test
# 1   Female         ECE        A     2020   1994-02-02        Test        Test
# 2     Male         ECE        A     2020   1993-08-06        Test        Test
# 3     Male         ECE        A     2020   1992-02-03        Test        Test
# 4   Female         ECE        A     2020   1991-02-03        Test        Test
#
#         Contact   Status
# ...

# %%
df['StudentName']
# Out:
# 0            Rahul Debnath
# 1     Humayra Tasnim Adiba
# 2              Mahin Ahsan
# 3             Kamrul Islam
# 4           Maysha Iyasmin
#               ...
# 56          Brayden Wright
# 57             Sofia Lopez
# 58          Zachary Harris
# 59          Avery Martinez
# 60          Isaac Thompson
# Name: StudentName, Length: 61, dtype: object

# %%
type(df['StudentName'])
# Out:
# pandas.core.series.Series

# %%
mycols = ['StudentName',' StudentEmail']
df[mycols]
# Out:
#              StudentName                   StudentEmail
# 0          Rahul Debnath     2010001@student.ruet.ac.bd
# 1   Humayra Tasnim Adiba     2010002@student.ruet.ac.bd
# 2            Mahin Ahsan     2010003@student.ruet.ac.bd
# 3           Kamrul Islam     2010004@student.ruet.ac.bd
# 4         Maysha Iyasmin     2010005@student.ruet.ac.bd
# ..                   ...                            ...
# 56        Brayden Wright   '2010057@student.ruet.ac.bd'
# 57           Sofia Lopez   '2010058@student.ruet.ac.bd'
# 58        Zachary Harris   '2010059@student.ruet.ac.bd'
# 59        Avery Martinez   '2010060@student.ruet.ac.bd'
# 60        Isaac Thompson   '2010061@student.ruet.ac.bd'
#
# [61 rows x 2 columns]

# %%
df[['StudentName', ' StudentEmail']]
# Out:
#              StudentName                   StudentEmail
# 0          Rahul Debnath     2010001@student.ruet.ac.bd
# 1   Humayra Tasnim Adiba     2010002@student.ruet.ac.bd
# 2            Mahin Ahsan     2010003@student.ruet.ac.bd
# 3           Kamrul Islam     2010004@student.ruet.ac.bd
# 4         Maysha Iyasmin     2010005@student.ruet.ac.bd
# ..                   ...                            ...
# 56        Brayden Wright   '2010057@student.ruet.ac.bd'
# 57           Sofia Lopez   '2010058@student.ruet.ac.bd'
# 58        Zachary Harris   '2010059@student.ruet.ac.bd'
# 59        Avery Martinez   '2010060@student.ruet.ac.bd'
# 60        Isaac Thompson   '2010061@student.ruet.ac.bd'
#
# [61 rows x 2 columns]

# %%
df['Testing'] = df[' RollId']/2000000

# %%
df.head()
# Out:
#             StudentName   RollId  RegistrationId                 StudentEmail  \
# 0         Rahul Debnath  2010001            1055   2010001@student.ruet.ac.bd
# 1  Humayra Tasnim Adiba  2010002            1056   2010002@student.ruet.ac.bd
# 2           Mahin Ahsan  2010003            1057   2010003@student.ruet.ac.bd
# 3          Kamrul Islam  2010004            1058   2010004@student.ruet.ac.bd
# 4        Maysha Iyasmin  2010005            1059   2010005@student.ruet.ac.bd
#
#     Gender  Department  Section   Series          DOB  FatherName  MotherName  \
# 0     Male         ECE        A     2020   1995-03-03        Test        Test
# 1   Female         ECE        A     2020   1994-02-02        Test        Test
# 2     Male         ECE        A     2020   1993-08-06        Test        Test
# 3     Male         ECE        A     2020   1992-02-03        Test        Test
# 4   Female         ECE        A     2020   1991-02-03        Test        Test
#
# ...

# %%
df['Testing'] = np.round(df[' RollId']/2000000,2)

# %%
df.head()
# Out:
#             StudentName   RollId  RegistrationId                 StudentEmail  \
# 0         Rahul Debnath  2010001            1055   2010001@student.ruet.ac.bd
# 1  Humayra Tasnim Adiba  2010002            1056   2010002@student.ruet.ac.bd
# 2           Mahin Ahsan  2010003            1057   2010003@student.ruet.ac.bd
# 3          Kamrul Islam  2010004            1058   2010004@student.ruet.ac.bd
# 4        Maysha Iyasmin  2010005            1059   2010005@student.ruet.ac.bd
#
#     Gender  Department  Section   Series          DOB  FatherName  MotherName  \
# 0     Male         ECE        A     2020   1995-03-03        Test        Test
# 1   Female         ECE        A     2020   1994-02-02        Test        Test
# 2     Male         ECE        A     2020   1993-08-06        Test        Test
# 3     Male         ECE        A     2020   1992-02-03        Test        Test
# 4   Female         ECE        A     2020   1991-02-03        Test        Test
#
# ...

# %%
df.drop('Testing', axis=1)
# Out:
#              StudentName   RollId  RegistrationId  \
# 0          Rahul Debnath  2010001            1055
# 1   Humayra Tasnim Adiba  2010002            1056
# 2            Mahin Ahsan  2010003            1057
# 3           Kamrul Islam  2010004            1058
# 4         Maysha Iyasmin  2010005            1059
# ..                   ...      ...             ...
# 56        Brayden Wright  2010057          '1111'
# 57           Sofia Lopez  2010058          '1112'
# 58        Zachary Harris  2010059          '1113'
# 59        Avery Martinez  2010060          '1114'
# 60        Isaac Thompson  2010061          '1115'
#
#                      StudentEmail     Gender  Department  Section   Series  \
# 0      2010001@student.ruet.ac.bd       Male         ECE        A     2020
# 1      2010002@student.ruet.ac.bd     Female         ECE        A     2020
# 2      2010003@student.ruet.ac.bd       Male         ECE        A     2020
# ...

# %%
df.shape
# Out:
# (61, 14)

# %%
df.index
# Out:
# RangeIndex(start=0, stop=61, step=1)

# %%
df.set_index(" RollId")
# Out:
#                   StudentName  RegistrationId                   StudentEmail  \
#  RollId
# 2010001         Rahul Debnath            1055     2010001@student.ruet.ac.bd
# 2010002  Humayra Tasnim Adiba            1056     2010002@student.ruet.ac.bd
# 2010003           Mahin Ahsan            1057     2010003@student.ruet.ac.bd
# 2010004          Kamrul Islam            1058     2010004@student.ruet.ac.bd
# 2010005        Maysha Iyasmin            1059     2010005@student.ruet.ac.bd
# ...                       ...             ...                            ...
# 2010057        Brayden Wright          '1111'   '2010057@student.ruet.ac.bd'
# 2010058           Sofia Lopez          '1112'   '2010058@student.ruet.ac.bd'
# 2010059        Zachary Harris          '1113'   '2010059@student.ruet.ac.bd'
# 2010060        Avery Martinez          '1114'   '2010060@student.ruet.ac.bd'
# 2010061        Isaac Thompson          '1115'   '2010061@student.ruet.ac.bd'
#
# ...

# %%
df.head()
# Out:
#             StudentName   RollId  RegistrationId                 StudentEmail  \
# 0         Rahul Debnath  2010001            1055   2010001@student.ruet.ac.bd
# 1  Humayra Tasnim Adiba  2010002            1056   2010002@student.ruet.ac.bd
# 2           Mahin Ahsan  2010003            1057   2010003@student.ruet.ac.bd
# 3          Kamrul Islam  2010004            1058   2010004@student.ruet.ac.bd
# 4        Maysha Iyasmin  2010005            1059   2010005@student.ruet.ac.bd
#
#     Gender  Department  Section   Series          DOB  FatherName  MotherName  \
# 0     Male         ECE        A     2020   1995-03-03        Test        Test
# 1   Female         ECE        A     2020   1994-02-02        Test        Test
# 2     Male         ECE        A     2020   1993-08-06        Test        Test
# 3     Male         ECE        A     2020   1992-02-03        Test        Test
# 4   Female         ECE        A     2020   1991-02-03        Test        Test
#
# ...

# %%
df = df.set_index(" RollId")

# %%
df.head()
# Out:
#          index           StudentName  RegistrationId  \
#  RollId
# 2010001      0         Rahul Debnath            1055
# 2010002      1  Humayra Tasnim Adiba            1056
# 2010003      2           Mahin Ahsan            1057
# 2010004      3          Kamrul Islam            1058
# 2010005      4        Maysha Iyasmin            1059
#
#                         StudentEmail   Gender  Department  Section   Series  \
#  RollId
# 2010001   2010001@student.ruet.ac.bd     Male         ECE        A     2020
# 2010002   2010002@student.ruet.ac.bd   Female         ECE        A     2020
# 2010003   2010003@student.ruet.ac.bd     Male         ECE        A     2020
# 2010004   2010004@student.ruet.ac.bd     Male         ECE        A     2020
# 2010005   2010005@student.ruet.ac.bd   Female         ECE        A     2020
#
#                  DOB  FatherName  MotherName       Contact   Status  Testing
#  RollId
# 2010001   1995-03-03        Test        Test   01912153465        1     1.01
# ...

# %%
df = df.reset_index()

# %%
df.head()
# Out:
#     RollId  index           StudentName  RegistrationId  \
# 0  2010001      0         Rahul Debnath            1055
# 1  2010002      1  Humayra Tasnim Adiba            1056
# 2  2010003      2           Mahin Ahsan            1057
# 3  2010004      3          Kamrul Islam            1058
# 4  2010005      4        Maysha Iyasmin            1059
#
#                   StudentEmail   Gender  Department  Section   Series  \
# 0   2010001@student.ruet.ac.bd     Male         ECE        A     2020
# 1   2010002@student.ruet.ac.bd   Female         ECE        A     2020
# 2   2010003@student.ruet.ac.bd     Male         ECE        A     2020
# 3   2010004@student.ruet.ac.bd     Male         ECE        A     2020
# 4   2010005@student.ruet.ac.bd   Female         ECE        A     2020
#
#            DOB  FatherName  MotherName       Contact   Status  Testing
# 0   1995-03-03        Test        Test   01912153465        1     1.01
# ...

# %%
df.iloc[0]
# Out:
#  RollId                                2010001
# index                                        0
# StudentName                      Rahul Debnath
#  RegistrationId                           1055
#  StudentEmail       2010001@student.ruet.ac.bd
#  Gender                                   Male
#  Department                                ECE
#  Section                                     A
#  Series                                   2020
#  DOB                                1995-03-03
#  FatherName                               Test
#  MotherName                               Test
#  Contact                           01912153465
#  Status                                      1
# Testing                                   1.01
# Name: 0, dtype: object

# %%
df.loc['2010006']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[88], line 1
# ----> 1 df.loc['2010006']
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1191, in _LocationIndexer.__getitem__(self, key)
#    1189 maybe_callable = com.apply_if_callable(key, self.obj)
#    1190 maybe_callable = self._check_deprecated_callable_usage(key, maybe_callable)
# -> 1191 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexing.py:1431, in _LocIndexer._getitem_axis(self, key, axis)
#    1429 # fall thru to straight lookup
#    1430 self._validate_key(key, axis)
# -> 1431 return self._get_label(key, axis=axis)
#
# ...

# %%
df.iloc[0:5]
# Out:
#     RollId  index           StudentName  RegistrationId  \
# 0  2010001      0         Rahul Debnath            1055
# 1  2010002      1  Humayra Tasnim Adiba            1056
# 2  2010003      2           Mahin Ahsan            1057
# 3  2010004      3          Kamrul Islam            1058
# 4  2010005      4        Maysha Iyasmin            1059
#
#                   StudentEmail   Gender  Department  Section   Series  \
# 0   2010001@student.ruet.ac.bd     Male         ECE        A     2020
# 1   2010002@student.ruet.ac.bd   Female         ECE        A     2020
# 2   2010003@student.ruet.ac.bd     Male         ECE        A     2020
# 3   2010004@student.ruet.ac.bd     Male         ECE        A     2020
# 4   2010005@student.ruet.ac.bd   Female         ECE        A     2020
#
#            DOB  FatherName  MotherName       Contact   Status  Testing
# 0   1995-03-03        Test        Test   01912153465        1     1.01
# ...

# %%
df.drop(' 2010061', axis=0)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[95], line 1
# ----> 1 df.drop(' 2010061', axis=0)
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
one_row = df.iloc[0]

# %%
one_row
# Out:
#  RollId                                2010001
# index                                        0
# StudentName                      Rahul Debnath
#  RegistrationId                           1055
#  StudentEmail       2010001@student.ruet.ac.bd
#  Gender                                   Male
#  Department                                ECE
#  Section                                     A
#  Series                                   2020
#  DOB                                1995-03-03
#  FatherName                               Test
#  MotherName                               Test
#  Contact                           01912153465
#  Status                                      1
# Testing                                   1.01
# Name: 0, dtype: object

# %%
df.append(one_row)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_9188\1271293785.py in ?()
# ----> 1 df.append(one_row)
#
# c:\Users\Lenovo\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'
